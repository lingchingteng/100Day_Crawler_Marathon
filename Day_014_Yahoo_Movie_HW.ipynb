# %% [markdown]
# # YAHOO電影爬蟲練習
# ## 練習爬取電影放映資訊。必須逐步獲取電影的代號、放映地區、放映日期後，再送出查詢給伺服器。

# %%
import requests
import re
from bs4 import BeautifulSoup

# %% [markdown]
# ### 先搜尋全部的電影代號(ID)資訊

# %%
# 查看目前上映那些電影，並擷取出其ID資訊
url = 'https://movies.yahoo.com.tw/'
resp = requests.get(url)
resp.encoding = 'utf-8'

soup = BeautifulSoup(resp.text, 'lxml')
html = soup.find("select", attrs={'name':'movie_id'})
movie_item = html.find_all("option", attrs={'data-name':re.compile('.*')})

for p in movie_item:
    print("Movie: %s, ID: %s" % (p["data-name"], p["value"]))
# Out:
# Movie: 菠蘿蜜, ID: 10412
# Movie: 韓影印象影展, ID: 10410
# Movie: 陰兒, ID: 10393
# Movie: 這一次不再錯過你, ID: 10389
# Movie: 別告訴她, ID: 10382
# Movie: 鬼屋實錄：惡魔之家, ID: 10378
# Movie: 驅魔直播, ID: 10375
# Movie: 真愛裁會贏, ID: 10362
# Movie: 那一夜, ID: 10345
# Movie: 兔嘲男孩, ID: 10283
# Movie: 海上鋼琴師4K數位修復, ID: 10425
# Movie: 鹿皮奇談, ID: 10420
# Movie: 大約在冬季, ID: 10408
# Movie: 倒數計死, ID: 10390
# Movie: 吹哨人, ID: 10381
# Movie: 幸福試用期, ID: 10374
# Movie: 竊竊屍語, ID: 10365
# Movie: 舞力決戰, ID: 10344
# Movie: 潛艦追緝, ID: 10333
# Movie: 霹靂嬌娃, ID: 10124
# Movie: 白頭山：半島浩劫, ID: 10354
# Movie: CATS貓, ID: 10166
# Movie: 金魚, ID: 10424
# Movie: 海上花, ID: 10376
# Movie: 怨靈古堡, ID: 10356
# Movie: 添好孕, ID: 10332
# Movie: 茱蒂, ID: 10112
# Movie: 燃燒女子的畫像, ID: 10069
# Movie: 葉問4：完結篇, ID: 9890
# Movie: STAR WARS : 天行者的崛起, ID: 10225
# Movie: 南方車站的聚會, ID: 10380
# Movie: 祭旗, ID: 10373
# Movie: 黑熊來了, ID: 10357
# Movie: 黑計畫, ID: 10351
# Movie: 假面騎士劇場版ZI-O Over Quartzer, ID: 10331
# Movie: 8級警戒, ID: 10323
# Movie: 為你存在的每一天, ID: 10297
# Movie: 黑色聖誕節, ID: 10291
# Movie: 大說謊家, ID: 10122
# Movie: 特約經紀公司, ID: 10364
# Movie: 人間失格：太宰治與他的3個女人, ID: 10287
# Movie: 呆萌特務, ID: 10264
# Movie: 去年聖誕節, ID: 10256
# Movie: 野蠻遊戲：全面晉級, ID: 10134
# Movie: 鋒迴路轉, ID: 10258
# Movie: 賽道狂人, ID: 10097
# Movie: 82年生的金智英, ID: 10298
# Movie: 冰雪奇緣2, ID: 9597
# Movie: 催眠．裁決, ID: 10322
# Movie: 新聞記者, ID: 10217
# Movie: 決戰中途島, ID: 10130
# Movie: 陽光普照, ID: 10240
# Movie: 傻傻愛你，傻傻愛我, ID: 10075
# Movie: 失憶的總理大臣, ID: 10246
# Movie: 金翅雀, ID: 10072
# Movie: 雙子殺手, ID: 10017
# Movie: 加油吧！李先生, ID: 10250
# Movie: 電影版 壞傢伙們, ID: 10249
# Movie: 江湖無難事, ID: 10241
# Movie: 仙戒奇緣, ID: 10211
# Movie: 藍波：最後一滴血, ID: 10205
# Movie: 屍樂園：髒比雙拼, ID: 10176
# Movie: 弒婚遊戲, ID: 10171
# Movie: 108悍將, ID: 10238
# Movie: 小丑, ID: 9949
# Movie: 教父II, ID: 10289
# Movie: 瞞天機密, ID: 10206
# Movie: 校外打怪教學, ID: 10200
# Movie: 無間行動, ID: 10155
# Movie: 囧媽的極地任務, ID: 7772
# Movie: 返校, ID: 10109
# Movie: 唐頓莊園, ID: 10064
# Movie: 衝擊真相, ID: 10215
# Movie: 舞孃騙很大, ID: 10199
# Movie: 好小男孩, ID: 9894
# Movie: 大叔之愛電影版, ID: 10136
# Movie: 極限逃生, ID: 10174
# Movie: 全面攻佔3：天使救援, ID: 10082
# Movie: 普羅米亞, ID: 10119
# Movie: 憤怒鳥玩電影2：冰的啦, ID: 10002
# Movie: 獅子王, ID: 9116
# Movie: 玩具總動員4, ID: 9924
# Movie: 毀滅者, ID: 9405
# Movie: 庫爾斯克號：深海救援, ID: 9134
# Movie: 厄夜追緝令, ID: 9589
# Movie: 苦兒流浪記, ID: 9538
# Movie: 活個精彩, ID: 9394
# Movie: 限時好友, ID: 9578
# Movie: 祝你忌日快樂, ID: 9568
# Movie: 艾莉塔：戰鬥天使, ID: 8553
# Movie: 馴龍高手3, ID: 8350
# Movie: 幸福綠皮書, ID: 9150
# Movie: 一首搖滾上月球, ID: 4887
# Movie: 錢不夠用2, ID: 3026
# Movie: 國際市場：半世紀的諾言, ID: 8273
# Movie: 當愛沉睡時, ID: 8080

# %% [markdown]
# ### 指定你有興趣的電影其ID，然後查詢其放映地區資訊。

# %%
# 參考前一個步驟中擷取到的ID資訊，並指定ID
movie_id = 10425

# %%
url = 'https://movies.yahoo.com.tw/api/v1/areas_by_movie_theater'
payload = {'movie_id':str(movie_id)}

# 模擬一個header
headers = {
    'authority': 'movies.yahoo.com.tw',
    'method': 'GET',
    'path': '/api/v1/areas_by_movie_theater?movie_id=' + str(movie_id),
    'scheme': 'https',
    'accept': 'application/json, text/javascript, */*; q=0.01',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6',
    'cookie': 'rxx=9s3x2fws06.1g16irnc&v=1; _ga=GA1.3.2056742944.1551651301; GUC=AQEBAQFczFpdm0IfmwSB&s=AQAAACoo4N5D&g=XMsVBw; BX=4hkdk1decm57t&b=3&s=mr; _ga=GA1.4.2056742944.1551651301; nexagesuid=82843256dd234e8e91aa73f2062f8218; browsed_movie=; avi=eyJpdiI6Im1NeWFJRlVRWDR1endEcGRGUGJUbVE9PSIsInZhbHVlIjoickRpU3JuUytmcGl6cjF5OW0rNU9iZz09IiwibWFjIjoiY2VmY2NkNzZmM2NhNjY5YzlkOTcyNjE5OGEyMzU0NWYxOTdmMDRkMDY3OWNmMmZjOTMxYjc5MjI5N2Q5NGE5MiJ9; cmp=t=1559391030&j=0; _gid=GA1.4.779543841.1559391031; XSRF-TOKEN=%3D; m_s=; _gat=1; nexagesd=10',
    'dnt': '1',
    'mv-authorization': '21835b082e15b91a69b3851eec7b31b82ce82afb',
    'referer': 'https://movies.yahoo.com.tw/',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36',
    'x-requested-with': 'XMLHttpRequest',
}
    
resp = requests.get(url, params=payload, headers=headers)
#print(resp.json())  # 若有需要，列印出json原始碼

# 這裡回傳的格式是JSON格式的資料，要解析JSON擷取資料
for p in resp.json():
    print('放映地區: {0}, 代號(area_id): {1}'.format(p['title'], p['area_id']))
# Out:
# 放映地區: 台北市, 代號(area_id): 28
# 放映地區: 新北市, 代號(area_id): 8
# 放映地區: 桃園, 代號(area_id): 16
# 放映地區: 新竹, 代號(area_id): 20
# 放映地區: 台中, 代號(area_id): 2
# 放映地區: 台南, 代號(area_id): 10
# 放映地區: 高雄, 代號(area_id): 17

# %% [markdown]
# ### 指定你想要觀看的放映地區，查詢有上映電影的場次日期

# %%
# 指定放映地區
area_id = 28

# %%
# 向網站發送請求
url = 'https://movies.yahoo.com.tw/movietime_result.html'
payload = {'movie_id':str(movie_id), 'area_id':str(area_id)}
resp = requests.get(url, params=payload)
resp.encoding = 'utf-8'

soup = BeautifulSoup(resp.text, 'lxml')
movie_date = soup.find_all("label", attrs={'for':re.compile("date_[\d]")})

# 列印播放日期
for date in movie_date:
    print("%s %s" % (date.p.string, date.h3.string))
# Out:
# 一月 4
# 一月 5
# 一月 6
# 一月 7
# 一月 8

# %% [markdown]
# ### 最後指定觀看的日期，查詢並列印出放映的電影院、放映類型(數位、3D、IMAX 3D...)、放映時間等資訊。

# %%
# 選定要觀看的日期
date = "2020-01-04"

# %%
# 向網站發送請求，獲取上映的電影院及時間資訊
url = "https://movies.yahoo.com.tw/ajax/pc/get_schedule_by_movie"
payload = {'movie_id':str(movie_id),
           'date':date,
           'area_id':str(area_id),
           'theater_id':'',
           'datetime':'',
           'movie_type_id':''}

resp = requests.get(url, params=payload)
print(resp.json()['view'])  # 若有需要，列印出json原始碼

soup = BeautifulSoup(resp.json()['view'], 'lxml')
html = soup.find_all("ul", attrs={'data-theater_name':re.compile(".*")})
# Out:
# <div class="pc-movie-schedule-form">
#     <div class="area_timebox">
#    <div class="area_title">台北市</div>
#       <ul id="theater_id_29" class="area_time _c jq_area_time" data-theater_name="國賓影城(台北長春廣場)" data-theater_url="http://www.ambassador.com.tw/" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=29" >
#        <li class="adds">
#            <a href="https://movies.yahoo.com.tw/theater_result.html/id=29">國賓影城(台北長春廣場)</a>
#            <span>02-25155755</span>
#        </li>
#                          <li class="taps">
#                 <span class="tapR">數位</span>                           </li>
#            <li class="time _c">
#                <div class="input_picker jq_input_picker">
#                                                    <input type="radio" name="schedule_list" id="72706892" class="gabtn"
#                         value="2020-01-04 10:50:00" data-movie_type="數位"
#                         data-movie_title="海上鋼琴師4K數位修復"
#                         data-movie_date="01.04"
#                         data-movie_time="10:50"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '海上鋼琴師4K數位修復']" data-news="news"
#                         />
#                     <label for="72706892" class="">10:50</label>
#                                                                     <input type="radio" name="schedule_list" id="72706893" class="gabtn"
#                         value="2020-01-04 13:05:00" data-movie_type="數位"
#                         data-movie_title="海上鋼琴師4K數位修復"
#                         data-movie_date="01.04"
#                         data-movie_time="13:05"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '海上鋼琴師4K數位修復']" data-news="news"
#                         />
#                     <label for="72706893" class="">13:05</label>
#                                                                     <input type="radio" name="schedule_list" id="72706894" class="gabtn"
#                         value="2020-01-04 17:35:00" data-movie_type="數位"
#                         data-movie_title="海上鋼琴師4K數位修復"
#                         data-movie_date="01.04"
#                         data-movie_time="17:35"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '海上鋼琴師4K數位修復']" data-news="news"
#                         />
#                     <label for="72706894" class="select">17:35</label>
#                                                                     <input type="radio" name="schedule_list" id="72706895" class="gabtn"
#                         value="2020-01-04 19:50:00" data-movie_type="數位"
#                         data-movie_title="海上鋼琴師4K數位修復"
#                         data-movie_date="01.04"
#                         data-movie_time="19:50"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '海上鋼琴師4K數位修復']" data-news="news"
#                         />
#                     <label for="72706895" class="select">19:50</label>
#                                                </div>
#            </li>
#           </ul>
#       <ul id="theater_id_41" class="area_time _c jq_area_time" data-theater_name="台北真善美劇院" data-theater_url="" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=41" >
#        <li class="adds">
#            <a href="https://movies.yahoo.com.tw/theater_result.html/id=41">台北真善美劇院</a>
#            <span>02-23312270</span>
#        </li>
#                          <li class="taps">
#                 <span class="tapR">數位</span>                           </li>
#            <li class="time _c">
#                <div class="input_picker jq_input_picker">
#                                                                    <input type="radio" name="schedule_list" id="72682626" class="gabtn"
#                         value="2020-01-04 18:40:00"  data-movie="4fbf9547079d4c34a8a58993f4b8a1f8"
#                         data-cinema="f644412efbb811e58858f2128151146f" data-session="fb59ebffe69a43d8a75b2a5fa9b6cdf8"
#                         data-date="1578067200" data-time="1578134400"
#                         data-movie_type="數位"
#                         data-movie_title="海上鋼琴師4K數位修復"
#                         data-movie_date="01.04"
#                         data-movie_time="18:40"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '海上鋼琴師4K數位修復']" data-ezding="ezding"
#                         />
#                     <label for="72682626" class="select">18:40</label>
#                                                                                     <input type="radio" name="schedule_list" id="72682627" class="gabtn"
#                         value="2020-01-04 22:50:00"  data-movie="4fbf9547079d4c34a8a58993f4b8a1f8"
#                         data-cinema="f644412efbb811e58858f2128151146f" data-session="2e6108bf575a4c01b0941a0b07bb10d5"
#                         data-date="1578067200" data-time="1578149400"
#                         data-movie_type="數位"
#                         data-movie_title="海上鋼琴師4K數位修復"
#                         data-movie_date="01.04"
#                         data-movie_time="22:50"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '海上鋼琴師4K數位修復']" data-ezding="ezding"
#                         />
#                     <label for="72682627" class="select">22:50</label>
#                                                </div>
#            </li>
#           </ul>
#       <ul id="theater_id_45" class="area_time _c jq_area_time" data-theater_name="台北信義威秀影城" data-theater_url="http://www.vscinemas.com.tw/" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=45" >
#        <li class="adds">
#            <a href="https://movies.yahoo.com.tw/theater_result.html/id=45">台北信義威秀影城</a>
#            <span>02-87805566</span>
#        </li>
#                          <li class="taps">
#                 <span class="tapR">數位</span>                           </li>
#            <li class="time _c">
#                <div class="input_picker jq_input_picker">
#                                                                    <input type="radio" name="schedule_list" id="72696514" class="gabtn"
#                         value="2020-01-04 16:50:00"  data-movie="5f3173f3a7af4a9998105149e7953023"
#                         data-cinema="40288eb0050f542401050f554e7e0674" data-session="ab9bcb05d2744c448ccff3032e13f1fe"
#                         data-date="1578067200" data-time="1578127800"
#                         data-movie_type="數位"
#                         data-movie_title="海上鋼琴師4K數位修復"
#                         data-movie_date="01.04"
#                         data-movie_time="16:50"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '海上鋼琴師4K數位修復']" data-ezding="ezding"
#                         />
#                     <label for="72696514" class="">16:50</label>
#                                                </div>
#            </li>
#           </ul>
#       <ul id="theater_id_152" class="area_time _c jq_area_time" data-theater_name="光點華山電影館" data-theater_url="http://www.spot-hs.org.tw/" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=152" >
#        <li class="adds">
#            <a href="https://movies.yahoo.com.tw/theater_result.html/id=152">光點華山電影館</a>
#            <span>02-23940622</span>
#        </li>
#                          <li class="taps">
#                 <span class="tapR">數位</span>                           </li>
#            <li class="time _c">
#                <div class="input_picker jq_input_picker">
#                                                    <input type="radio" name="schedule_list" id="72708882" class="gabtn"
#                         value="2020-01-04 14:50:00" data-movie_type="數位"
#                         data-movie_title="海上鋼琴師4K數位修復"
#                         data-movie_date="01.04"
#                         data-movie_time="14:50"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '海上鋼琴師4K數位修復']" data-news="news"
#                         />
#                     <label for="72708882" class="">14:50</label>
#                                                </div>
#            </li>
#           </ul>
#       <ul id="theater_id_168" class="area_time _c jq_area_time" data-theater_name="誠品電影院" data-theater_url="https://meet.eslite.com/tw/tc/gallery/201803020001" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=168" >
#        <li class="adds">
#            <a href="https://movies.yahoo.com.tw/theater_result.html/id=168">誠品電影院</a>
#            <span>02-66365888</span>
#        </li>
#                          <li class="taps">
#                 <span class="tapR">數位</span>                           </li>
#            <li class="time _c">
#                <div class="input_picker jq_input_picker">
#                                                    <input type="radio" name="schedule_list" id="72709060" class="gabtn"
#                         value="2020-01-04 10:30:00" data-movie_type="數位"
#                         data-movie_title="海上鋼琴師4K數位修復"
#                         data-movie_date="01.04"
#                         data-movie_time="10:30"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '海上鋼琴師4K數位修復']" data-news="news"
#                         />
#                     <label for="72709060" class="">10:30</label>
#                                                                     <input type="radio" name="schedule_list" id="72709061" class="gabtn"
#                         value="2020-01-04 17:40:00" data-movie_type="數位"
#                         data-movie_title="海上鋼琴師4K數位修復"
#                         data-movie_date="01.04"
#                         data-movie_time="17:40"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '海上鋼琴師4K數位修復']" data-news="news"
#                         />
#                     <label for="72709061" class="select">17:40</label>
#                                                </div>
#            </li>
#           </ul>
#       <ul id="theater_id_186" class="area_time _c jq_area_time" data-theater_name="喜樂時代影城南港店" data-theater_url="http://www.centuryasia.com.tw/default.aspx" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=186" >
#        <li class="adds">
#            <a href="https://movies.yahoo.com.tw/theater_result.html/id=186">喜樂時代影城南港店</a>
#            <span>02-27888185</span>
#        </li>
#                          <li class="taps">
#                 <span class="tapR">數位</span>                           </li>
#            <li class="time _c">
#                <div class="input_picker jq_input_picker">
#                                                                    <input type="radio" name="schedule_list" id="72704707" class="gabtn"
#                         value="2020-01-04 20:15:00"  data-movie="f17c7b7a64aa486bafd88eca37165739"
#                         data-cinema="40288eb0050f542401050f5681782dc5" data-session="002705a536974369b0cfe974de198574"
#                         data-date="1578067200" data-time="1578140100"
#                         data-movie_type="數位"
#                         data-movie_title="海上鋼琴師4K數位修復"
#                         data-movie_date="01.04"
#                         data-movie_time="20:15"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '海上鋼琴師4K數位修復']" data-ezding="ezding"
#                         />
#                     <label for="72704707" class="select">20:15</label>
#                                                </div>
#            </li>
#           </ul>
#    </div>
#
#     <div class="booking_modal jq_booking_modal">
#     <div class="booking_modal_backdrop"></div>
#     <!-- 時報訂票 ＆ 有官網訂票 新增 class => no_seats -->
#     <div class="booking_modal_content jq_booking_modal_content">
#         <form method="get" action="https://movies.yahoo.com.tw/ticket/ezding_ticket" target="_blank" id="form_schedule">
#                 <div class="ezding_ticket_value">
#             <input type="hidden" name="movie_id" value="">
#             <input type="hidden" name="cinema_id" value="">
#             <input type="hidden" name="session_id" value="">
#             <input type="hidden" name="date" value="">
#             <input type="hidden" name="time" value="">
#             <input type="hidden" name="campaign_code" value="yahoopc">
#         </div>
#         <ul class="top_infos">
#             <li>
#                 <p>片名</p>
#                 <h3 id="top_infos_movie"></h3>
#             </li>
#             <li>
#                 <p>影城</p>
#                 <h3 id="top_infos_theater"></h3>
#             </li>
#             <li>
#                 <p>日期</p>
#                 <h3 id="top_infos_date"></h3>
#             </li>
#             <li>
#                 <p>版本</p>
#                 <h3 id="top_infos_movie_type"></h3>
#             </li>
#             <li>
#                 <p>時間</p>
#                 <h3 id="top_infos_time"></h3>
#             </li>
#         </ul>
#
#         <div class="booking_seats">
#             <a href="#" class="theater_schedules gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_一般戲院_全部電影場次', '']">全部電影場次</a>
#             <a href="#" class="theater_url gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_一般戲院_官網訂票', '']" target="_blank">官網訂票</a>
#             <p id="no_theater_url" class="no_theater_url">無提供官網訂票</p>
#
#             <p id="booking_number" class="booking_number">人數</p>
#             <div class="booking_seat_group jq_booking_seat_group">
#                                     <input type="radio" name="tickets" id="seat_1" value="1" />
#                     <label for="seat_1">1</label>
#                                     <input type="radio" name="tickets" id="seat_2" value="2"  checked />
#                     <label for="seat_2">2</label>
#                                     <input type="radio" name="tickets" id="seat_3" value="3" />
#                     <label for="seat_3">3</label>
#                                     <input type="radio" name="tickets" id="seat_4" value="4" />
#                     <label for="seat_4">4</label>
#                                     <input type="radio" name="tickets" id="seat_5" value="5" />
#                     <label for="seat_5">5</label>
#                                     <input type="radio" name="tickets" id="seat_6" value="6" />
#                     <label for="seat_6">6</label>
#                             </div>
#             <button type="submit" class="action_btn action_booking_btn jq_booking_btn gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_一般戲院_選位', '']">選位</button>
#             <a href="#" class="action_btn action_link jq_booking_link gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_時報戲院_官網選位', '']" target="_blank">官網訂票</a>
#             <button type="button" class="action_btn close jq_close_booking_btn">關閉</button>
#         </div>
#         </form>
#
#         <!-- 無官網訂票區塊 -->
#         <div class="no_theater_section">
#             <p>無提供官網訂票</p>
#             <button type="button" class="action_btn close jq_close_booking_btn">關閉</button>
#         </div>
#     </div>
# </div></div>

# %%
for ul in html:
    theater_name = ul.find('li', attrs={'class': 'adds'}).find('a')
    print(theater_name.text)
    
    for time in ul.find('li', attrs={'class': 'time'}).find_all('input'):
        print(
            time['data-movie_type'], 
            time['data-movie_title'], 
            time['data-movie_date'], 
            time['data-movie_time'])
# Out:
# 國賓影城(台北長春廣場)
# 數位 海上鋼琴師4K數位修復 01.04 10:50
# 數位 海上鋼琴師4K數位修復 01.04 13:05
# 數位 海上鋼琴師4K數位修復 01.04 17:35
# 數位 海上鋼琴師4K數位修復 01.04 19:50
# 台北真善美劇院
# 數位 海上鋼琴師4K數位修復 01.04 18:40
# 數位 海上鋼琴師4K數位修復 01.04 22:50
# 台北信義威秀影城
# 數位 海上鋼琴師4K數位修復 01.04 16:50
# 光點華山電影館
# 數位 海上鋼琴師4K數位修復 01.04 14:50
# 誠品電影院
# 數位 海上鋼琴師4K數位修復 01.04 10:30
# 數位 海上鋼琴師4K數位修復 01.04 17:40
# 喜樂時代影城南港店
# 數位 海上鋼琴師4K數位修復 01.04 20:15
